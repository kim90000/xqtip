# %%
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
import torch

model_id = "relaxml/Llama-2-7b-QTIP-2Bit"

# تحميل التوكنلايزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحميل النموذج باستخدام `AutoModelForCausalLM`
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # استخدم FP16 لتوفير الذاكرة
    device_map="auto"  # لتشغيله على GPU تلقائيًا
)

# إنشاء `pipeline` لمعالجة النصوص
text_gen = pipeline("text-generation", model=model, tokenizer=tokenizer)

# تجربة تشغيل النموذج
prompt = "The capital of France is"
output = text_gen(prompt, max_length=50, do_sample=True)

print(output[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-0dbac834dc97> in <cell line: 0>()
#       5
#       6 # تحميل التوكنلايزر
# ----> 7 tokenizer = AutoTokenizer.from_pretrained(model_id)
#       8
#       9 # تحميل النموذج باستخدام `AutoModelForCausalLM`
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     951
#     952             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 953                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     954             else:
#     955                 if tokenizer_class_py is not None:
#
# ...

# %%
# !huggingface-cli login --token ْْْْْْْْْْْْْْْْْXXXXXXXXXXX
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `read` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `read`

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_path = "relaxml/Llama-2-7b-QTIP-2Bit"

# تحميل التوكنلايزر الأصلي لـ LLaMA-2
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")

# تحميل النموذج من safetensors
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16)

# اختبار النموذج
input_ids = tokenizer("The capital of France is", return_tensors="pt").input_ids
output = model.generate(input_ids)

print(tokenizer.decode(output[0]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
